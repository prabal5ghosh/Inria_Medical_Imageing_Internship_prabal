# %% [markdown]
# **Prabal Ghosh**

# %% [markdown]
#   **Testing MRI features avaliable in Total Segmentator**

# %%
import nibabel as nib
from pathlib import Path
from totalsegmentator.python_api import totalsegmentator
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
import torch
print(torch.__version__)
# Out:
# 2.3.1

# %%
# !pip install pytest
# Out:
# ...
#   Using cached pluggy-1.5.0-py3-none-any.whl.metadata (4.8 kB)
# ...
# Using cached pluggy-1.5.0-py3-none-any.whl (20 kB)
# ...

# %%
from nibabel.testing import data_path

# %%
example_filename = os.path.join(data_path, 'example4d.nii.gz')

# %%
import nibabel as nib
img = nib.load(example_filename)

# %%
img.shape
# Out:
# (128, 96, 24, 2)

# %%
type(img)
# Out:
# nibabel.nifti1.Nifti1Image

# %%
img.header

# %% [markdown]
# # 0. data

# %%
input_path_1 = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0005/mri.nii.gz")
# output_path_1 = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0005/segmentations")

# %%
# img = nib.load(input_path_1)
img = nib.load(input_path_1).get_fdata()   # it will convert the NIfTI image to a numpy array

img.shape
# Out:
# (256, 17, 256)

# %%
type(img)
# Out:
# nibabel.nifti1.Nifti1Image

# %%
# img.header

# %%
print(f"The .nii files are stored in memory as numpy's: {type(img)}.")
# Out:
# The .nii files are stored in memory as numpy's: <class 'numpy.ndarray'>.

# %%
plt.style.use('default')
fig, axes = plt.subplots(4,4, figsize=(12,12))
for i, ax in enumerate(axes.reshape(-1)):
    ax.imshow(img[:,:,1 + i])
plt.show()

# %% [markdown]
# # 1. total_mr

# %%
input_path_1 = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0005/mri.nii.gz")
output_path_1 = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0005/segmentations_total_mr")

# %% [markdown]
# ## model option 1

# %%
if __name__ == "__main__":

    # Segment the first MRI image
    print(f"Segmenting {input_path_1}...")
    # totalsegmentator(input=input_path_1, output=output_path_1, task="total_mr", fast=True, roi_subset=["kidney_left","liver","stomach","heart","lung_left"])
    # totalsegmentator(input=input_path_1, output=output_path_1, task="total_mr", fastest=True, roi_subset=["gluteus_maximus_left","gluteus_maximus_right","gluteus_medius_left","gluteus_medius_right","gluteus_minimus_left","gluteus_minimus_right","iliopsoas_left","iliopsoas_right"])
    # totalsegmentator(input=input_path_1, output=output_path_1, task="total_mr", fastest=True, roi_subset=["gluteus_maximus_left","gluteus_medius_right","gluteus_minimus_left","iliopsoas_right"])
    
    totalsegmentator(input=input_path_1, output=output_path_1, task="total_mr", roi_subset=["lung_left", "lung_right", "heart", "stomach", "liver","gluteus_maximus_left","gluteus_medius_right","gluteus_minimus_left","iliopsoas_right"], fast = True)


    print(f"Segmentation completed for {input_path_1}. Results saved to {output_path_1}.")
# Out:
# Segmenting c:\Users\praba\Documents\GitHub\Inria_Medical_Imageing_Internship_prabal\s0005\mri.nii.gz...
# No GPU detected. Running on CPU. This can be very slow. The '--fast' or the `--roi_subset` option can help to reduce runtime.
#
# If you use this tool please cite: https://pubs.rsna.org/doi/10.1148/ryai.230024
#
# Using 'fast' option: resampling to lower resolution (3mm)
# Generating rough segmentation for cropping...
# Resampling...
#   Resampled in 0.55s
# Predicting...
# 100%|██████████| 6/6 [00:36<00:00,  6.14s/it]
#   Predicted in 75.50s
# Resampling...
#   cropping from (256, 17, 256) to (187, 17, 245)
# Resampling...
#   Resampled in 0.39s
# Predicting...
# 100%|██████████| 3/3 [00:16<00:00,  5.41s/it]
#   Predicted in 50.80s
# Resampling...
# Saving segmentations...
#   Saved in 24.98s
# ...

# %%
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/kidney_left.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/brain.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/heart.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0010/segmentations/liver.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/stomach.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/gluteus_maximus_left.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/gluteus_medius_right.nii.gz")

# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/gluteus_minimus_left.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/iliopsoas_right.nii.gz")


output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0005/segmentations_total_mr/lung_left.nii.gz")

# %%
img = nib.load(output_path).get_fdata()
img.shape
# Out:
# (256, 17, 256)

# %%
print(f"The .nii files are stored in memory as numpy's: {type(img)}.")
# Out:
# The .nii files are stored in memory as numpy's: <class 'numpy.ndarray'>.

# %%
img.shape[2]
# Out:
# 256

# %%
# %matplotlib inline
plt.style.use('default')
plt.figure(figsize=(5,5))
ax = plt.subplot(1, 1, 1)
ax.set_title("Original Image")
ax.axis('off')  

# Average across the third dimension
projected_img = img.mean(axis=2)
plt.imshow(projected_img)

plt.show()

# %%
plt.style.use('default')
fig, axes = plt.subplots(7, 6, figsize=(20, 20))

# Ensure the loop does not exceed the number of slices in the third axis
for i, ax in enumerate(axes.reshape(-1)):
    if i + 1 < img.shape[2]:  # Check if the index is within bounds
        ax.imshow(img[:, :, 1 + i])
    else:
        ax.axis('off')  # Turn off the axis if no slice is available

plt.show()

# %% [markdown]
# ## model option 2

# %%
if __name__ == "__main__":

    # Segment the first MRI image
    print(f"Segmenting {input_path_1}...")

    # option 2
    input_img = nib.load(input_path_1)
    # output_img = totalsegmentator(input_img,task="total_mr", fastest=True, roi_subset=["kidney_left"])
    # output_img = totalsegmentator(input_img,task="total_mr", fastest=True, roi_subset=["kidney_left","liver","stomach","heart","brain"])
    output_img = totalsegmentator(input_img,task="total_mr", roi_subset=["lung_left", "lung_right", "heart", "stomach", "liver","gluteus_maximus_left","gluteus_medius_right","gluteus_minimus_left","iliopsoas_right"])

    nib.save(output_img, output_path_1)
    print(f"Segmentation completed for {input_path_1}. Results saved to {output_path_1}.")
# Out:
# Segmenting c:\Users\praba\Documents\GitHub\Inria_Medical_Imageing_Internship_prabal\s0005\mri.nii.gz...
# No GPU detected. Running on CPU. This can be very slow. The '--fast' or the `--roi_subset` option can help to reduce runtime.
#
# If you use this tool please cite: https://pubs.rsna.org/doi/10.1148/ryai.230024
#
# Generating rough segmentation for cropping...
# Resampling...
#   Resampled in 0.53s
# Predicting...
# 100%|██████████| 6/6 [00:35<00:00,  5.95s/it]
#   Predicted in 72.91s
# Resampling...
#   cropping from (256, 17, 256) to (187, 17, 245)
# Resampling...
#   Resampled in 2.89s
# Predicting part 1 of 2 ...
# 100%|██████████| 10/10 [02:41<00:00, 16.17s/it]
# Predicting part 2 of 2 ...
# 100%|██████████| 10/10 [01:56<00:00, 11.69s/it]
#   Predicted in 366.40s
# Resampling...
# ...

# %%
# output_path_2 = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations.nii")
output_path_2 = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0005/segmentations_total_mr.nii")

# %%
img = nib.load(output_path_2).get_fdata()
img.shape
# Out:
# (256, 17, 256)

# %%
print(f"The .nii files are stored in memory as numpy's: {type(img)}.")
# Out:
# The .nii files are stored in memory as numpy's: <class 'numpy.memmap'>.

# %%
# %matplotlib inline
plt.style.use('default')
plt.figure(figsize=(5, 5))
ax = plt.subplot(1, 1, 1)
ax.set_title("segmented Image")
ax.axis('off')  

# Average across the third dimension
projected_img = img.mean(axis=2)
plt.imshow(projected_img)

plt.show()

# %%
plt.style.use('default')
fig, axes = plt.subplots(7, 6, figsize=(20, 20))

# Ensure the loop does not exceed the number of slices in the third axis
for i, ax in enumerate(axes.reshape(-1)):
    if i + 1 < img.shape[2]:  # Check if the index is within bounds
        ax.imshow(img[:, :, 1 + i])
    else:
        ax.axis('off')  # Turn off the axis if no slice is available

plt.show()

# %% [markdown]
# # 2. body_mr

# %%
input_path_1 = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0005/mri.nii.gz")
output_path_1 = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0005/segmentations_body_mr")

# %% [markdown]
# ## model option 1

# %%
if __name__ == "__main__":

    # Segment the first MRI image
    print(f"Segmenting {input_path_1}...")
    # totalsegmentator(input=input_path_1, output=output_path_1, task="total_mr", fast=True, roi_subset=["kidney_left","liver","stomach","heart","lung_left"])
    # totalsegmentator(input=input_path_1, output=output_path_1, task="total_mr", fastest=True, roi_subset=["gluteus_maximus_left","gluteus_maximus_right","gluteus_medius_left","gluteus_medius_right","gluteus_minimus_left","gluteus_minimus_right","iliopsoas_left","iliopsoas_right"])
    # totalsegmentator(input=input_path_1, output=output_path_1, task="total_mr", fastest=True, roi_subset=["gluteus_maximus_left","gluteus_medius_right","gluteus_minimus_left","iliopsoas_right"])
    
    totalsegmentator(input=input_path_1, output=output_path_1, task="body_mr")


    print(f"Segmentation completed for {input_path_1}. Results saved to {output_path_1}.")
# Out:
# Segmenting c:\Users\praba\Documents\GitHub\Inria_Medical_Imageing_Internship_prabal\s0005\mri.nii.gz...
# No GPU detected. Running on CPU. This can be very slow. The '--fast' or the `--roi_subset` option can help to reduce runtime.
#
# If you use this tool please cite: https://pubs.rsna.org/doi/10.1148/ryai.230024
#
# Resampling...
#   Resampled in 4.82s
# Predicting...
# 100%|██████████| 20/20 [04:25<00:00, 13.26s/it]
#   Predicted in 325.26s
# Resampling...
# Saving segmentations...
#   Saved in 17.07s
# Segmentation completed for c:\Users\praba\Documents\GitHub\Inria_Medical_Imageing_Internship_prabal\s0005\mri.nii.gz. Results saved to c:\Users\praba\Documents\GitHub\Inria_Medical_Imageing_Internship_prabal\s0005\segmentations_body_mr.

# %%
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/kidney_left.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/brain.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/heart.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0010/segmentations/liver.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/stomach.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/gluteus_maximus_left.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/gluteus_medius_right.nii.gz")

# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/gluteus_minimus_left.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/iliopsoas_right.nii.gz")


output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0005/segmentations_body_mr/body_extremities.nii.gz")

# %%
img = nib.load(output_path).get_fdata()
img.shape
# Out:
# (256, 17, 256)

# %%
print(f"The .nii files are stored in memory as numpy's: {type(img)}.")
# Out:
# The .nii files are stored in memory as numpy's: <class 'numpy.ndarray'>.

# %%
img.shape[2]
# Out:
# 256

# %%
# %matplotlib inline
plt.style.use('default')
plt.figure(figsize=(5,5))
ax = plt.subplot(1, 1, 1)
ax.set_title("Original Image")
ax.axis('off')  

# Average across the third dimension
projected_img = img.mean(axis=2)
plt.imshow(projected_img)

plt.show()

# %%
plt.style.use('default')
fig, axes = plt.subplots(7, 6, figsize=(20, 20))

# Ensure the loop does not exceed the number of slices in the third axis
for i, ax in enumerate(axes.reshape(-1)):
    if i + 1 < img.shape[2]:  # Check if the index is within bounds
        ax.imshow(img[:, :, 1 + i])
    else:
        ax.axis('off')  # Turn off the axis if no slice is available

plt.show()

# %% [markdown]
# # 3. vertebrae_mr

# %%
input_path_1 = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0005/mri.nii.gz")
output_path_1 = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0005/segmentations_vertebrae_mr")

# %% [markdown]
# ## model option 1

# %%
if __name__ == "__main__":

    # Segment the first MRI image
    print(f"Segmenting {input_path_1}...")
    # totalsegmentator(input=input_path_1, output=output_path_1, task="total_mr", fast=True, roi_subset=["kidney_left","liver","stomach","heart","lung_left"])
    # totalsegmentator(input=input_path_1, output=output_path_1, task="total_mr", fastest=True, roi_subset=["gluteus_maximus_left","gluteus_maximus_right","gluteus_medius_left","gluteus_medius_right","gluteus_minimus_left","gluteus_minimus_right","iliopsoas_left","iliopsoas_right"])
    # totalsegmentator(input=input_path_1, output=output_path_1, task="total_mr", fastest=True, roi_subset=["gluteus_maximus_left","gluteus_medius_right","gluteus_minimus_left","iliopsoas_right"])
    
    totalsegmentator(input=input_path_1, output=output_path_1, task="vertebrae_mr")


    print(f"Segmentation completed for {input_path_1}. Results saved to {output_path_1}.")
# Out:
# Segmenting c:\Users\praba\Documents\GitHub\Inria_Medical_Imageing_Internship_prabal\s0005\mri.nii.gz...
# No GPU detected. Running on CPU. This can be very slow. The '--fast' or the `--roi_subset` option can help to reduce runtime.
#
# If you use this tool please cite: https://pubs.rsna.org/doi/10.1148/ryai.230024
#
# Predicting...
# 100%|██████████| 15/15 [05:40<00:00, 22.71s/it]
#   Predicted in 506.92s
# Saving segmentations...
#   Saved in 25.22s
# Segmentation completed for c:\Users\praba\Documents\GitHub\Inria_Medical_Imageing_Internship_prabal\s0005\mri.nii.gz. Results saved to c:\Users\praba\Documents\GitHub\Inria_Medical_Imageing_Internship_prabal\s0005\segmentations_vertebrae_mr.

# %%
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/kidney_left.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/brain.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/heart.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0010/segmentations/liver.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/stomach.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/gluteus_maximus_left.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/gluteus_medius_right.nii.gz")

# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/gluteus_minimus_left.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/iliopsoas_right.nii.gz")


output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0005/segmentations_vertebrae_mr/sacrum.nii.gz")

# %%
img = nib.load(output_path).get_fdata()
img.shape
# Out:
# (256, 17, 256)

# %%
print(f"The .nii files are stored in memory as numpy's: {type(img)}.")
# Out:
# The .nii files are stored in memory as numpy's: <class 'numpy.ndarray'>.

# %%
img.shape[2]
# Out:
# 256

# %%
# %matplotlib inline
plt.style.use('default')
plt.figure(figsize=(5,5))
ax = plt.subplot(1, 1, 1)
ax.set_title("Original Image")
ax.axis('off')  

# Average across the third dimension
projected_img = img.mean(axis=2)
plt.imshow(projected_img)

plt.show()

# %%
plt.style.use('default')
fig, axes = plt.subplots(7, 6, figsize=(20, 20))

# Ensure the loop does not exceed the number of slices in the third axis
for i, ax in enumerate(axes.reshape(-1)):
    if i + 1 < img.shape[2]:  # Check if the index is within bounds
        ax.imshow(img[:, :, 1 + i])
    else:
        ax.axis('off')  # Turn off the axis if no slice is available

plt.show()

# %% [markdown]
# # 4. liver_segments_mr

# %%
input_path_1 = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0005/mri.nii.gz")
output_path_1 = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0005/segmentations_liver_segments_mr")

# %% [markdown]
# ## model option 1

# %%
if __name__ == "__main__":

    # Segment the first MRI image
    print(f"Segmenting {input_path_1}...")
    # totalsegmentator(input=input_path_1, output=output_path_1, task="total_mr", fast=True, roi_subset=["kidney_left","liver","stomach","heart","lung_left"])
    # totalsegmentator(input=input_path_1, output=output_path_1, task="total_mr", fastest=True, roi_subset=["gluteus_maximus_left","gluteus_maximus_right","gluteus_medius_left","gluteus_medius_right","gluteus_minimus_left","gluteus_minimus_right","iliopsoas_left","iliopsoas_right"])
    # totalsegmentator(input=input_path_1, output=output_path_1, task="total_mr", fastest=True, roi_subset=["gluteus_maximus_left","gluteus_medius_right","gluteus_minimus_left","iliopsoas_right"])
    
    totalsegmentator(input=input_path_1, output=output_path_1, task="liver_segments_mr")


    print(f"Segmentation completed for {input_path_1}. Results saved to {output_path_1}.")
# Out:
# Segmenting c:\Users\praba\Documents\GitHub\Inria_Medical_Imageing_Internship_prabal\s0005\mri.nii.gz...
# No GPU detected. Running on CPU. This can be very slow. The '--fast' or the `--roi_subset` option can help to reduce runtime.
#
# If you use this tool please cite: https://pubs.rsna.org/doi/10.1148/ryai.230024
#
# Generating rough segmentation for cropping...
# Resampling...
#   Resampled in 0.54s
# Predicting...
# 100%|██████████| 6/6 [00:33<00:00,  5.51s/it]
#   Predicted in 63.52s
# Resampling...
#   cropping from (256, 17, 256) to (105, 17, 132)
# Resampling...
#   Resampled in 0.72s
# Predicting...
# 100%|██████████| 2/2 [00:20<00:00, 10.28s/it]
#   Predicted in 52.80s
# Resampling...
# Saving segmentations...
#   Saved in 19.63s
# Segmentation completed for c:\Users\praba\Documents\GitHub\Inria_Medical_Imageing_Internship_prabal\s0005\mri.nii.gz. Results saved to c:\Users\praba\Documents\GitHub\Inria_Medical_Imageing_Internship_prabal\s0005\segmentations_liver_segments_mr.

# %%
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/kidney_left.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/brain.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/heart.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0010/segmentations/liver.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/stomach.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/gluteus_maximus_left.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/gluteus_medius_right.nii.gz")

# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/gluteus_minimus_left.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/iliopsoas_right.nii.gz")


output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0005/segmentations_liver_segments_mr/liver_segment_1.nii.gz")

# %%
img = nib.load(output_path).get_fdata()
img.shape
# Out:
# (256, 17, 256)

# %%
print(f"The .nii files are stored in memory as numpy's: {type(img)}.")
# Out:
# The .nii files are stored in memory as numpy's: <class 'numpy.ndarray'>.

# %%
img.shape[2]
# Out:
# 256

# %%
# %matplotlib inline
plt.style.use('default')
plt.figure(figsize=(5,5))
ax = plt.subplot(1, 1, 1)
ax.set_title("Original Image")
ax.axis('off')  

# Average across the third dimension
projected_img = img.mean(axis=2)
plt.imshow(projected_img)

plt.show()

# %%
plt.style.use('default')
fig, axes = plt.subplots(7, 6, figsize=(20, 20))

# Ensure the loop does not exceed the number of slices in the third axis
for i, ax in enumerate(axes.reshape(-1)):
    if i + 1 < img.shape[2]:  # Check if the index is within bounds
        ax.imshow(img[:, :, 1 + i])
    else:
        ax.axis('off')  # Turn off the axis if no slice is available

plt.show()

# %% [markdown]
# # 5. appendicular_bones_mr

# %%
input_path_1 = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0005/mri.nii.gz")
output_path_1 = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0005/segmentations_appendicular_bones_mr")

# %% [markdown]
# ## model option 1

# %%
if __name__ == "__main__":

    # Segment the first MRI image
    print(f"Segmenting {input_path_1}...")
    # totalsegmentator(input=input_path_1, output=output_path_1, task="total_mr", fast=True, roi_subset=["kidney_left","liver","stomach","heart","lung_left"])
    # totalsegmentator(input=input_path_1, output=output_path_1, task="total_mr", fastest=True, roi_subset=["gluteus_maximus_left","gluteus_maximus_right","gluteus_medius_left","gluteus_medius_right","gluteus_minimus_left","gluteus_minimus_right","iliopsoas_left","iliopsoas_right"])
    # totalsegmentator(input=input_path_1, output=output_path_1, task="total_mr", fastest=True, roi_subset=["gluteus_maximus_left","gluteus_medius_right","gluteus_minimus_left","iliopsoas_right"])
    
    totalsegmentator(input=input_path_1, output=output_path_1, task="appendicular_bones_mr")


    print(f"Segmentation completed for {input_path_1}. Results saved to {output_path_1}.")
# Out:
# Segmenting c:\Users\praba\Documents\GitHub\Inria_Medical_Imageing_Internship_prabal\s0005\mri.nii.gz...
# No GPU detected. Running on CPU. This can be very slow. The '--fast' or the `--roi_subset` option can help to reduce runtime.
#
# If you use this tool please cite: https://pubs.rsna.org/doi/10.1148/ryai.230024
#
# ...
# Downloading: 100%|██████████| 232M/232M [00:54<00:00, 4.28MB/s]
# Download finished. Extracting...
# Resampling...
#   Resampled in 4.04s
# Predicting...
# 100%|██████████| 15/15 [02:40<00:00, 10.69s/it]
#   Predicted in 192.72s
# Resampling...
# Saving segmentations...
#   Saved in 26.51s
# Segmentation completed for c:\Users\praba\Documents\GitHub\Inria_Medical_Imageing_Internship_prabal\s0005\mri.nii.gz. Results saved to c:\Users\praba\Documents\GitHub\Inria_Medical_Imageing_Internship_prabal\s0005\segmentations_appendicular_bones_mr.

# %%
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/kidney_left.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/brain.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/heart.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0010/segmentations/liver.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/stomach.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/gluteus_maximus_left.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/gluteus_medius_right.nii.gz")

# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/gluteus_minimus_left.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/iliopsoas_right.nii.gz")


output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0005/segmentations_appendicular_bones_mr/radius.nii.gz")

# %%
img = nib.load(output_path).get_fdata()
img.shape
# Out:
# (256, 17, 256)

# %%
print(f"The .nii files are stored in memory as numpy's: {type(img)}.")
# Out:
# The .nii files are stored in memory as numpy's: <class 'numpy.ndarray'>.

# %%
img.shape[2]
# Out:
# 256

# %%
# %matplotlib inline
plt.style.use('default')
plt.figure(figsize=(5,5))
ax = plt.subplot(1, 1, 1)
ax.set_title("Original Image")
ax.axis('off')  

# Average across the third dimension
projected_img = img.mean(axis=2)
plt.imshow(projected_img)

plt.show()

# %%
plt.style.use('default')
fig, axes = plt.subplots(7, 6, figsize=(20, 20))

# Ensure the loop does not exceed the number of slices in the third axis
for i, ax in enumerate(axes.reshape(-1)):
    if i + 1 < img.shape[2]:  # Check if the index is within bounds
        ax.imshow(img[:, :, 1 + i])
    else:
        ax.axis('off')  # Turn off the axis if no slice is available

plt.show()

# %% [markdown]
# # 6. tissue_types_mr

# %%
input_path_1 = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0005/mri.nii.gz")
output_path_1 = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0005/segmentations_tissue_types_mr")

# %% [markdown]
# ## model option 1

# %%
if __name__ == "__main__":

    # Segment the first MRI image
    print(f"Segmenting {input_path_1}...")
    # totalsegmentator(input=input_path_1, output=output_path_1, task="total_mr", fast=True, roi_subset=["kidney_left","liver","stomach","heart","lung_left"])
    # totalsegmentator(input=input_path_1, output=output_path_1, task="total_mr", fastest=True, roi_subset=["gluteus_maximus_left","gluteus_maximus_right","gluteus_medius_left","gluteus_medius_right","gluteus_minimus_left","gluteus_minimus_right","iliopsoas_left","iliopsoas_right"])
    # totalsegmentator(input=input_path_1, output=output_path_1, task="total_mr", fastest=True, roi_subset=["gluteus_maximus_left","gluteus_medius_right","gluteus_minimus_left","iliopsoas_right"])
    
    totalsegmentator(input=input_path_1, output=output_path_1, task="tissue_types_mr")


    print(f"Segmentation completed for {input_path_1}. Results saved to {output_path_1}.")
# Out:
# Segmenting c:\Users\praba\Documents\GitHub\Inria_Medical_Imageing_Internship_prabal\s0005\mri.nii.gz...
# No GPU detected. Running on CPU. This can be very slow. The '--fast' or the `--roi_subset` option can help to reduce runtime.
#
# If you use this tool please cite: https://pubs.rsna.org/doi/10.1148/ryai.230024
#
# ...
# Downloading: 100%|██████████| 230M/230M [01:07<00:00, 3.42MB/s]
# Download finished. Extracting...
# Resampling...
#   Resampled in 3.94s
# Predicting...
# 100%|██████████| 15/15 [02:16<00:00,  9.11s/it]
#   Predicted in 173.47s
# Resampling...
# Saving segmentations...
#   Saved in 15.22s
# Segmentation completed for c:\Users\praba\Documents\GitHub\Inria_Medical_Imageing_Internship_prabal\s0005\mri.nii.gz. Results saved to c:\Users\praba\Documents\GitHub\Inria_Medical_Imageing_Internship_prabal\s0005\segmentations_tissue_types_mr.

# %%
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/kidney_left.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/brain.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/heart.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0010/segmentations/liver.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/stomach.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/gluteus_maximus_left.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/gluteus_medius_right.nii.gz")

# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/gluteus_minimus_left.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/iliopsoas_right.nii.gz")


output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0005/segmentations_tissue_types_mr/subcutaneous_fat.nii.gz")

# %%
img = nib.load(output_path).get_fdata()
img.shape
# Out:
# (256, 17, 256)

# %%
print(f"The .nii files are stored in memory as numpy's: {type(img)}.")
# Out:
# The .nii files are stored in memory as numpy's: <class 'numpy.ndarray'>.

# %%
img.shape[2]
# Out:
# 256

# %%
# %matplotlib inline
plt.style.use('default')
plt.figure(figsize=(5,5))
ax = plt.subplot(1, 1, 1)
ax.set_title("Original Image")
ax.axis('off')  

# Average across the third dimension
projected_img = img.mean(axis=2)
plt.imshow(projected_img)

plt.show()

# %%
plt.style.use('default')
fig, axes = plt.subplots(7, 6, figsize=(20, 20))

# Ensure the loop does not exceed the number of slices in the third axis
for i, ax in enumerate(axes.reshape(-1)):
    if i + 1 < img.shape[2]:  # Check if the index is within bounds
        ax.imshow(img[:, :, 1 + i])
    else:
        ax.axis('off')  # Turn off the axis if no slice is available

plt.show()

# %% [markdown]
# # 7. thigh_shoulder_muscles_mr

# %%
input_path_1 = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0005/mri.nii.gz")
output_path_1 = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0005/segmentations_shoulder_muscles_mr")

# %% [markdown]
# ## model option 1

# %%
if __name__ == "__main__":

    # Segment the first MRI image
    print(f"Segmenting {input_path_1}...")
    # totalsegmentator(input=input_path_1, output=output_path_1, task="total_mr", fast=True, roi_subset=["kidney_left","liver","stomach","heart","lung_left"])
    # totalsegmentator(input=input_path_1, output=output_path_1, task="total_mr", fastest=True, roi_subset=["gluteus_maximus_left","gluteus_maximus_right","gluteus_medius_left","gluteus_medius_right","gluteus_minimus_left","gluteus_minimus_right","iliopsoas_left","iliopsoas_right"])
    # totalsegmentator(input=input_path_1, output=output_path_1, task="total_mr", fastest=True, roi_subset=["gluteus_maximus_left","gluteus_medius_right","gluteus_minimus_left","iliopsoas_right"])
    
    totalsegmentator(input=input_path_1, output=output_path_1, task="thigh_shoulder_muscles_mr")


    print(f"Segmentation completed for {input_path_1}. Results saved to {output_path_1}.")
# Out:
# Segmenting c:\Users\praba\Documents\GitHub\Inria_Medical_Imageing_Internship_prabal\s0005\mri.nii.gz...
# No GPU detected. Running on CPU. This can be very slow. The '--fast' or the `--roi_subset` option can help to reduce runtime.
#
# If you use this tool please cite: https://pubs.rsna.org/doi/10.1148/ryai.230024
#
# ...
# Downloading: 100%|██████████| 232M/232M [00:59<00:00, 3.90MB/s]
# Download finished. Extracting...
# Resampling...
#   Resampled in 4.10s
# Predicting...
# 100%|██████████| 15/15 [02:43<00:00, 10.88s/it]
#   Predicted in 204.53s
# Resampling...
# Saving segmentations...
#   Saved in 29.32s
# Segmentation completed for c:\Users\praba\Documents\GitHub\Inria_Medical_Imageing_Internship_prabal\s0005\mri.nii.gz. Results saved to c:\Users\praba\Documents\GitHub\Inria_Medical_Imageing_Internship_prabal\s0005\segmentations_shoulder_muscles_mr.

# %%
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/kidney_left.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/brain.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/heart.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0010/segmentations/liver.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/stomach.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/gluteus_maximus_left.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/gluteus_medius_right.nii.gz")

# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/gluteus_minimus_left.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/iliopsoas_right.nii.gz")


output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0005/segmentations_shoulder_muscles_mr/quadriceps_femoris_left.nii.gz")

# %%
img = nib.load(output_path).get_fdata()
img.shape
# Out:
# (256, 17, 256)

# %%
print(f"The .nii files are stored in memory as numpy's: {type(img)}.")
# Out:
# The .nii files are stored in memory as numpy's: <class 'numpy.ndarray'>.

# %%
img.shape[2]
# Out:
# 256

# %%
# %matplotlib inline
plt.style.use('default')
plt.figure(figsize=(5,5))
ax = plt.subplot(1, 1, 1)
ax.set_title("Original Image")
ax.axis('off')  

# Average across the third dimension
projected_img = img.mean(axis=2)
plt.imshow(projected_img)

plt.show()

# %%
plt.style.use('default')
fig, axes = plt.subplots(7, 6, figsize=(20, 20))

# Ensure the loop does not exceed the number of slices in the third axis
for i, ax in enumerate(axes.reshape(-1)):
    if i + 1 < img.shape[2]:  # Check if the index is within bounds
        ax.imshow(img[:, :, 1 + i])
    else:
        ax.axis('off')  # Turn off the axis if no slice is available

plt.show()

# %% [markdown]
# # 8. face_mr

# %%
input_path_1 = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0005/mri.nii.gz")
output_path_1 = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0005/segmentations_face_mr")

# %% [markdown]
# ## model option 1

# %%
if __name__ == "__main__":

    # Segment the first MRI image
    print(f"Segmenting {input_path_1}...")
    # totalsegmentator(input=input_path_1, output=output_path_1, task="total_mr", fast=True, roi_subset=["kidney_left","liver","stomach","heart","lung_left"])
    # totalsegmentator(input=input_path_1, output=output_path_1, task="total_mr", fastest=True, roi_subset=["gluteus_maximus_left","gluteus_maximus_right","gluteus_medius_left","gluteus_medius_right","gluteus_minimus_left","gluteus_minimus_right","iliopsoas_left","iliopsoas_right"])
    # totalsegmentator(input=input_path_1, output=output_path_1, task="total_mr", fastest=True, roi_subset=["gluteus_maximus_left","gluteus_medius_right","gluteus_minimus_left","iliopsoas_right"])
    
    totalsegmentator(input=input_path_1, output=output_path_1, task="face_mr")


    print(f"Segmentation completed for {input_path_1}. Results saved to {output_path_1}.")
# Out:
# Segmenting c:\Users\praba\Documents\GitHub\Inria_Medical_Imageing_Internship_prabal\s0005\mri.nii.gz...
# No GPU detected. Running on CPU. This can be very slow. The '--fast' or the `--roi_subset` option can help to reduce runtime.
#
# If you use this tool please cite: https://pubs.rsna.org/doi/10.1148/ryai.230024
#
# ...
# Downloading: 100%|██████████| 231M/231M [01:03<00:00, 3.61MB/s]
# Download finished. Extracting...
# Resampling...
#   Resampled in 4.32s
# Predicting...
# 100%|██████████| 15/15 [02:33<00:00, 10.25s/it]
#   Predicted in 193.01s
# Resampling...
# Saving segmentations...
#   Saved in 12.75s
# Segmentation completed for c:\Users\praba\Documents\GitHub\Inria_Medical_Imageing_Internship_prabal\s0005\mri.nii.gz. Results saved to c:\Users\praba\Documents\GitHub\Inria_Medical_Imageing_Internship_prabal\s0005\segmentations_face_mr.

# %%
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/kidney_left.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/brain.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/heart.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0010/segmentations/liver.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/stomach.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/gluteus_maximus_left.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/gluteus_medius_right.nii.gz")

# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/gluteus_minimus_left.nii.gz")
# output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0001/segmentations/iliopsoas_right.nii.gz")


output_path = Path("c:/Users/praba/Documents/GitHub/Inria_Medical_Imageing_Internship_prabal/s0005/segmentations_face_mr/face.nii.gz")

# %%
img = nib.load(output_path).get_fdata()
img.shape
# Out:
# (256, 17, 256)

# %%
print(f"The .nii files are stored in memory as numpy's: {type(img)}.")
# Out:
# The .nii files are stored in memory as numpy's: <class 'numpy.ndarray'>.

# %%
img.shape[2]
# Out:
# 256

# %%
# %matplotlib inline
plt.style.use('default')
plt.figure(figsize=(5,5))
ax = plt.subplot(1, 1, 1)
ax.set_title("Original Image")
ax.axis('off')  

# Average across the third dimension
projected_img = img.mean(axis=2)
plt.imshow(projected_img)

plt.show()

# %%
plt.style.use('default')
fig, axes = plt.subplots(7, 6, figsize=(20, 20))

# Ensure the loop does not exceed the number of slices in the third axis
for i, ax in enumerate(axes.reshape(-1)):
    if i + 1 < img.shape[2]:  # Check if the index is within bounds
        ax.imshow(img[:, :, 1 + i])
    else:
        ax.axis('off')  # Turn off the axis if no slice is available

plt.show()
